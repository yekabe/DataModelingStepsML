# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.DataFrame({'A': ['a', 'b', 'a'], 'B': ['b', 'a', 'c'], 'C': [1, 2, 3]})

# %%
df
# Out:
#    A  B  C
# 0  a  b  1
# 1  b  a  2
# 2  a  c  3

# %%
pd.get_dummies(df)   # or prefix=['col1', 'col2']
# Out:
#    C  A_a  A_b  B_a  B_b  B_c
# 0  1    1    0    0    1    0
# 1  2    0    1    1    0    0
# 2  3    1    0    0    0    1

# %%
temp = df
temp.A = temp.A.map({'a': 0, 'b': 1, 'c': 2})
temp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-648a34b05fdf> in <module>
#       1 temp = df
# ----> 2 temp = temp.map({'a': 0, 'b': 1, 'c': 2})
#       3 temp
#
# ~/opt/anaconda3/envs/phd_analysis/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
df = sns.load_dataset('titanic')

# %%
pd.crosstab(index=df.sex, columns="count", margins=True)
# Out:
# col_0   count  All
# sex
# female    314  314
# male      577  577
# All       891  891

# %%
pd.crosstab(index=df["alive"], columns=df["sex"])
# Out:
# sex    female  male
# alive
# no         81   468
# yes       233   109

# %%
pd.crosstab(index=df["alive"], columns=df["sex"], margins=True)
# Out:
# sex    female  male  All
# alive
# no         81   468  549
# yes       233   109  342
# All       314   577  891

# %%
temp = pd.crosstab(index=df["alive"], columns=[df["pclass"], df["sex"]], margins=True)
temp
# Out:
# pclass      1           2           3       All
# sex    female male female male female male
# alive
# no          3   77      6   91     72  300  549
# yes        91   45     70   17     72   47  342
# All        94  122     76  108    144  347  891

# %%
temp/temp.loc["All"] # Probability
# Out:
# pclass         1                   2                3                 All
# sex       female      male    female      male female      male
# alive
# no      0.031915  0.631148  0.078947  0.842593    0.5  0.864553  0.616162
# yes     0.968085  0.368852  0.921053  0.157407    0.5  0.135447  0.383838
# All     1.000000  1.000000  1.000000  1.000000    1.0  1.000000  1.000000

# %%
temp = df.stack()
temp = pd.DataFrame(temp)
temp = x.reset_index()
temp
# Out:
#    index  level_0 level_1  0
# 0      0        0       A  0
# 1      1        0       B  b
# 2      2        0       C  1
# 3      3        1       A  1
# 4      4        1       B  a
# 5      5        1       C  2
# 6      6        2       A  0
# 7      7        2       B  c
# 8      8        2       C  3
