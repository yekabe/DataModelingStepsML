# %% [markdown]
# <a class="anchor" id="0.1"></a>
#
# # Time Series Modeling in Brief and Applications
#
# By Data Science Group, Summer 2020
#
# # Table of Contents
# 1. [Time Series Models](#TSM)
#
#     - [What is Time Series?](#TSM.W)
#     - [Type of Time Series models](#TSM.T)
#     - [Some ML Models TS models](#TSM.MK)
#
#
# 2. [Concepts and Models in Details](#CD)
#
#     - Concepts
#     - Models
#     - Examples
#
#
# 3. [Building Model](#BM)
#
#     - [Practical Guide in Preprocessing and Building a TS Model](#PG)
#
#
# 4. [Data Analysis](#DA)
#
#     - Ice Cream data
#     - Other data sets
#
#
# # Resources
# [Minitab's link](https://support.minitab.com/en-us/minitab/19/help-and-how-to/statistical-modeling/time-series/how-to/decomposition/perform-the-analysis/enter-your-data/?SID=22500)
#
# [TS in Python](https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/)
#
# [TS in Python](https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/)
#
# [More math on TS](http://people.cs.pitt.edu/~milos/courses/cs3750/lectures/class16.pdf)
#
# [Full Example from Jason](https://machinelearningmastery.com/time-series-forecast-study-python-monthly-sales-french-champagne/)
#
# [Online Text from https://www.itl.nist.gov/](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc4463.htm)
#
# # Explore More
#
# https://github.com/yekabe/DataModelingStepsML/blob/master/notebooks/deep_learning/price_precitions/Homework_3_Kamil.ipynb
#
# https://www.kaggle.com/c/walmart-recruiting-store-sales-forecasting
#
# https://www.quora.com/When-should-I-use-an-RNN-LSTM-and-when-to-use-ARIMA-for-a-time-series-forecasting-problem-What-is-the-relation-between-them?share=1
#
# https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/
#
# https://machinelearningmastery.com/time-series-forecast-study-python-monthly-sales-french-champagne/
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc45.htm

# %% [markdown]
# # 1. Time Series Models <div id='TSM'/> <a class="anchor" id="TSM"></a>
#
# ## What is Time Series? <div id='TSM.W'/>
#
# - Time series (TS) is different from more traditional classification and regression predictive modeling problems. The temporal structure adds an order to the observations. In time series, the addition of a trend, seasonality, and other time-dependent structures complicate the independent model assumptions.
#
# - The purpose of time series analysis is generally two-fold: to understand or model the stochastic mechanisms that gives rise to an observed series and to predict or forecast the future values of a series based on the history of that series.
#
# - There are a number of approaches to modeling time series. We outline a few of the most common approaches.
#     1. Trend, Seasonal, Residual Decompositions: One approach is to decompose the time series into a trend, seasonal, and residual component. Triple exponential smoothing is an example of this approach.
#     2. Another approach, commonly used in scientific and engineering applications, is to analyze the series in the frequency domain. An example of this approach in modeling a sinusoidal type data set is shown in the beam deflection case study. The spectral plot is the primary tool for the frequency analysis of time series.
#     3. A common approach for modeling univariate time series is the autoregressive (AR) model or its variants.
#
#
# ## Types of TS <div id='TSM.T'/>
#
# When modeling variations in the level of a process, four broad classes of practical importance are:
#
# - the autoregressive (AR) models,
# - the integrated (I) models,
# - the moving average (MA), and
# - seasonal (S).
#
# Also,
#
# - the acronyms with "X" are for "exogenous", so exogenous (X) models would be the fifth one.
# - The autoregressive fractionally integrated moving average (ARFIMA) model generalizes the former four models. Extensions of these classes to deal with vector-valued data (multivariate outcome) are available under the heading of multivariate time-series models and sometimes the preceding acronyms are extended by including an initial "V" for "vector", as in VAR for vector autoregression.
#
# These classes depend linearly on previous data points. Combinations of these ideas produce autoregressive moving average (ARMA), autoregressive integrated moving average (ARIMA), and SARIMAX models.
#
# 1. Autoregression (AR)
# 2. Moving Average (MA)
# 3. Autoregressive Moving Average (ARMA)
# 4. Autoregressive Integrated Moving Average (ARIMA)
# 5. Seasonal Autoregressive Integrated Moving-Average (SARIMA)
# 6. Seasonal Autoregressive Integrated Moving-Average with Exogenous Regressors (SARIMAX)
# 7. Vector Autoregression (VAR)
# 8. Vector Autoregression Moving-Average (VARMA)
# 9. Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX)
# 10. Simple Exponential Smoothing (SES)
# 11. Holt Winter’s Exponential Smoothing (HWES)
# 12. ...
#
#
# ## Some ML Models TS are:** <div id='TSM.ML'/>
#
# 1. Long Short-Term Memory (LSTM) is a type of recurrent neural network that can learn the order dependence between items in a sequence. LSTMs have the promise of being able to learn the context required to make predictions in time series forecasting problems, rather than having this context pre-specified and fixed.
# 2. Recurrent Neural Network (RNN)
# 3. K-Nearest Neighbor regression (KNN)
# 4. In recent work on model-free analyses, wavelet transform based methods (for example locally stationary wavelets and wavelet decomposed neural networks) have gained favor.
#
# Conceptually, we will cover details on the models here. Some data examples will be presented as well.

# %% [markdown]
# # 2. Concepts and Models in Details <div id='CD'/>
#
# ## TS Components
#
# The decomposition of a time series into 4 constituent parts: $y = level + trend + seasonality + noise$
#
# 1. Level. The baseline value for the series if it were a straight line.
# 2. Trend. The optional and often linear increasing or decreasing behavior of the series over time.
# 3. Seasonality. The optional repeating patterns or cycles of behavior over time.
# 4. Noise. The optional variability in the observations that cannot be explained by the model.
# 5. Others.
#
# ### Decomposition Examples
#
# Resource: [Minitab's link on decomposition](https://support.minitab.com/en-us/minitab/19/help-and-how-to/statistical-modeling/time-series/how-to/decomposition/perform-the-analysis/enter-your-data/?SID=22500%5D)
#
# - Seasonal only:
# - Trend plus seasonal:
# - With multiplicative data, the magnitude of the seasonal pattern changes as the level of the data changes:
# - With additive data, the magnitude of the seasonal pattern remains constant as the level of the data changes:
# - [Trend and Seasonal decomposition analyzed in Minitab](https://support.minitab.com/en-us/minitab/19/help-and-how-to/statistical-modeling/time-series/how-to/decomposition/before-you-start/example/)
#
#
# ### Various Trends:
#
# Choose the seasonal pattern that fits your data. Determine whether your data has a trend.
#
# - Linear
# The data fits a line, which indicates that the rate of change is uniform over time. The model is $Yt = β0 + (β1 * t) + et.$ In this model, β1 represents the average change from one period to the next.
#
# - Quadratic
# The data have a curvature, which indicates that the rate of change varies over time. The model is $Yt = β0+ β1 * t + (β2* t2) + et.$
#
# - Exponential growth
# The data have a steep curvature, which indicates that the rate of change varies more quickly over time. For example, a savings account might exhibit exponential growth. The model is $Yt = β0 * β1t * et.$
#
# - S-Curve (Pearl-Reed logistic)
# The data has an S-shape, which indicates that the direction of the change varies over time. The model is $Yt = (c) / (β0 + β1 * β2t).$
#
#
# ### Stationary Process
#
# - A common assumption in many time series techniques is that the data are stationary. A stationary process has the property that the mean, variance and autocorrelation structure do not change over time.
#
# - A stationary process is a stochastic process whose unconditional joint probability distribution does not change when shifted in time. Consequently, parameters such as mean and variance also do not change over time.
#     - One way to make some time series stationary is to compute the differences between consecutive observations. This is known as differencing.
#     - Transformations such as logarithms can help to stabilize the variance of a time series. Differencing can help stabilize the mean of a time series by removing changes in the level of a time series, and so eliminating trend and seasonality.
#     - One of the ways for identifying non-stationary times series is the ACF plot. For a stationary time series, the ACF will drop to zero relatively quickly, while the ACF of non-stationary data decreases slowly.
#
# - Should you make your time series stationary? YES! So our first step in an analysis should be to check whether there is any evidence of a trend or seasonal effects and, if there is, remove them. The methods to check:
#     - Look at Plots:  You can review a time series plot of your data and visually check if there are any obvious trends or seasonality.
#         - The run sequence plot can also give the analyst an excellent feel for the data. Check the time series is random or not: has is a high degree of autocorrelation between adjacent and near-adjacent observations?
#         - Autocorrelation plots are a commonly-used tool for checking randomness in a data set. This randomness is ascertained by computing autocorrelations for data values at varying time lags. If random, such autocorrelations should be near zero for any and all time-lag separations. If non-random, then one or more of the autocorrelations will be significantly non-zero.
#         - A lag plot, y_t vs y_(t-1), checks whether a data set or time series is random or not. Random data should not exhibit any identifiable structure in the lag plot. Do more lags, get correlations. Lag plots can provide answers to the following questions: Are the data random? Is there serial correlation in the data? What is a suitable model for the data? Are there outliers in the data?
#     - Summary Statistics: You can review the summary statistics for your data for seasons or random partitions and check for obvious or significant differences.
#     - Statistical Tests: You can use statistical tests to check if the expectations of stationarity are met or have been violated.
#
# - Discover how to check if your time series is stationary:
#     - Time series are stationary if they do not have trend or seasonal effects. Summary statistics calculated on the time series are consistent over time, like the mean or the variance of the observations.
#     - Non-stationary shows both trend and seasonal components.
#     - Types of stationary:
#         - Stationary Process: A process that generates a stationary series of observations.
#         - Stationary Model: A model that describes a stationary series of observations.
#         - Trend Stationary: A time series that does not exhibit a trend.
#         - Seasonal Stationary: A time series that does not exhibit seasonality.
#         - Strictly Stationary: A mathematical definition of a stationary process, specifically that the joint distribution of observations is invariant to time shift.
#
# - There are 2 major reasons behind non-stationarity of a TS:
#     1. Trend – varying mean over time. For eg, in this case we saw that on average, the number of passengers was growing over time.
#     2. Seasonality – variations at specific time-frames. eg people might have a tendency to buy cars in a particular month because of pay increment or festivals.
#
# - You can split your time series into two (or more) partitions and compare the mean and variance of each group. If they differ and the difference is statistically significant, the time series is likely non-stationary. [See](https://machinelearningmastery.com/time-series-data-stationary-python/) for data sets and examples.
#
# - Although seasonality also violates stationarity, this is usually explicitly incorporated (taken care) into the time series model.
#
# - If the time series is not stationary, we can often transform it to stationarity with one of the following techniques.
#     - We can difference the data.
#     - If the data contain a trend, we can fit some type of curve to the data and then model the residuals from that fit. Since the purpose of the fit is to simply remove long term trend, a simple fit, such as a straight line, is typically used.
#     - For non-constant variance, taking the logarithm or square root of the series may stabilize the variance. For negative data, you can add a suitable constant to make all the data positive before applying the transformation. This constant can then be subtracted from the model to obtain predicted (i.e., the fitted) values and forecasts for future points.
#
#
# ## Models
#
# ### Moving Average (MA)
#
# - Another common approach for modeling univariate time series models is the moving average (MA) model: $Xt=μ+At−θ1*At−1−θ2*At−2−...−θq*At−q,$ where Xt is the time series, μ is the mean of the series, At−i are white noise terms, and θ1,…,θq are the parameters of the model. The value of q is called the order of the MA model.
#
# - A **moving average model** is conceptually a linear regression of the current value of the series against the white noise or random shocks of one or more prior values of the series. Fitting the MA estimates is more complicated than with AR models because the error terms are not observable. This means that iterative non-linear fitting procedures need to be used in place of linear least squares.
#
# - Let's assume the set of numbers 9, 8, 9, 12, 9, 12, 11, 7, 13, 9, 11, 10 are the dollar amount of 12 suppliers selected at random. Let us set n, the size of the "smaller set" equal to 3. Then the average of the first 3 numbers is:   (9 + 8 + 9) / 3 = 8.667. This is called "smoothing" (i.e., some form of averaging). This smoothing process is continued by advancing one period and calculating the next average of three numbers, dropping the first number.
#
# - Recent observations are given relatively more weight in forecasting than the older observations. In the case of moving averages, the weights assigned to the observations are the same and are equal to 1/N.
#
# - Nonseasonal Moving Average's **term (q)** is the number of previous error terms (lags of the forecast errors) that affect the current value. To determine the nonseasonal MA term, look at the partial autocorrelation function. For more information, to go partial autocorrelation function.
#
# - The **partial autocorrelation (PACF)** at lag k is the autocorrelation between Xt and Xt−k that is not accounted for by lags 1 through k−1. [Visit](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc4463.htm)
#
# - For Moving Average, the number of consecutive observations is needed calculate the moving averages. If there is a seasonal pattern, you can set the length equal to the length of the seasonal pattern. The moving average length adjusts the amount of smoothing. Typically, smooth the data enough to reduce the noise (irregular fluctuations) so that the pattern is more apparent. However, don't smooth the data so much that you lose important details. Lower values produce a less smooth line. Higher values produce a smoother line. To calculate naive forecasts, use a moving average length of 1. With a moving average value of 5, it calculates the average of the first 5 values and plots it at position 5.
#
# ### Simple and Holt Winter’s Exponential Smoothing (SES, HWES)
#
# - Whereas in Single Moving Averages the past observations are weighted equally, Exponential Smoothing assigns exponentially decreasing weights as the observation get older.
#
# - The Simple Exponential Smoothing (SES) method models the next time step as an exponentially weighted linear function of observations at prior time steps.
#
# - The SES method is suitable for univariate time series without trend and seasonal components.
#
# - In exponential smoothing, however, there are one or more smoothing parameters to be determined (or estimated) and these choices determine the weights assigned to the observations. The speed at which the older responses are dampened (smoothed) is a function of the value of α. [Visit](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc431.htm).
#
# - Single Exponential Smoothing (short for single exponential smoothing) is not very good ? when there is a trend. This situation can be improved by the introduction of a second equation with a second constant. Double Exponential Smoothing (LASP) helps to forecast ts data with trend only.
#
# -  If it is desired to portray the growth process in a more aggressive manner, then one selects double smoothing. Otherwise, regression may be preferable. It should be noted that in linear regression "time" functions as the independent variable.
#
# - What happens if the data show trend and seasonality? Include a third equation to take care of seasonality (sometimes called periodicity). The resulting set of equations is called the "Holt-Winters" (HW-ES) method.
#
# - The **Holt Winter’s Exponential Smoothing (HWES)** also called the Triple Exponential Smoothing method models the next time step as an exponentially weighted linear function of observations at prior time steps, taking trends and seasonality into account.
#
# - Add trend: additive, multiplicative, none. Then use HWES for ice cream data. Consider coefficients for demand (alpha), for trend (γ) and for seasonality (β). [Visit](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc435.htm)
#
# ### Seasonality Component (S)
#
# - By seasonality, we mean periodic fluctuations. For example, retail sales tend to peak for the Christmas season and then decline after the holidays. So time series of retail sales will typically show increasing sales from September through December and declining sales in January and February.
#
# - The following graphical techniques can be used to detect seasonality.
#     - A run sequence plot will often show seasonality.
#     - A seasonal subseries plot is a specialized technique for showing seasonality. [Visit]([https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc4431.htm)
#     - Multiple box plots can be used as an alternative to the seasonal subseries plot to detect seasonality.
#     - The autocorrelation plot can help identify seasonality.
#
# - The **autocorrelation plot** shows an alternating pattern of positive and negative spikes when seasonal effects present. [Discuss](https://www.itl.nist.gov/div898/handbook/pmc/section4/pmc4462.htm).
#
# - Seasonality component may suggest an exponential growth from season to season. A log transform can be used to flatten out exponential change back to a linear relationship or to a trend non-stationary structure.
#
# - You must have at least 2 full seasons of data to perform the analysis. However, it is recommended that you have 4 to 5 full seasonal cycles. If you do not have enough full cycles, you many not have enough data to calculate reasonable estimates of the seasonal indices.
#
# - In Seasonal length, enter the number of observations that occur in one season. For example, if you collect data monthly and they have a yearly pattern, enter 12. If you do not know the seasonal length, use Time Series Plot or Autocorrelation to help you identify the length.
#
# - Nonseasonal Difference (d) indicates the number of times you subtract the previous data value from the current data value. If you don't know the number, try the following: If the data do not have a trend and the mean is relatively constant, enter 0. If the trend is linear or if the mean is not constant, enter 1. If there is a trend that is not constant and linear, enter 2.
#
# - Seasonal Difference (D) if the data exhibits a seasonal pattern. 1 is sufficient for most seasonal patterns.
#
# - Seasonal Moving average MA term (Q) if the data exhibits a seasonal pattern. 1 is sufficient for most seasonal patterns.
#
# - The seasonal indices are the seasonal effects at time t. Use the indices to seasonally adjust the data, either by dividing the data by the seasonal indices (multiplicative model) or by subtracting the seasonal indices from the data (additive model).
#
# - Model a seasonal effect in a multiplicative way.
#
# ## Autocorrelations
#
# ### Autocorrelation (AR)
#
# - Autocorrelation is the correlation between observations of a time series. 'cor(x_t, x_(t-1))'
#
# - An **autoregressive model** is simply a linear regression of the current value of the series against one or more prior values of the series. The value of p is called the order of the AR model.
#
# - A common approach for modeling univariate time series is the autoregressive (AR) model: $Xt=δ+ϕ1*X_(t−1)+ϕ2*X_(t−2)+⋯+ϕp*X_(t−p)+At$
#
# - A nonseasonal AR (p) is the number of previous values (lags) that affect the current value. If you don't know the number, try the following: If no lags are significantly correlated, enter 0. If lags are significantly correlated, enter 1 or 2. Use autocorrelation to determine whether lags are significantly correlated.
#
# - A Seasonal AR (P) is the number of lags from the previous season that are significantly correlated with the current season. 1 is sufficient for most seasonal patterns. Use autocorrelation to determine whether lags from the previous season are significantly correlated.
#
# ### Partial autocorrelation (PACF)
#
# - The **partial autocorrelation (PACF)** is the correlation between observations in a time series that is not accounted for by all of the shorter intervals between those observations. For example, the partial autocorrelation for a lag of 6 is only the correlation that is not accounted for by lags 1 through 5. The plot of partial autocorrelations is called the partial autocorrelation function (PACF). View the PACF to guide your choice of terms to include in an ARIMA model.
#
# - We generate a partial autocorrelation plot to help identify the order after we detect correlation in autocorrelation plot.
#
# - For example, for monthly data we would typically include either a seasonal AR 12 term or a seasonal MA 12 term. For weekly, this is 7.
#
#
# ### Moving Average Integrated Autoregressive (ARIMA)
#
# - **Box-Jenkins** popularized an approach that combines the moving average and the autoregressive approaches. The Box-Jenkins model assumes that the time series is stationary. Box and Jenkins recommend differencing non-stationary series one or more times to achieve stationarity. Doing so produces an ARIMA model, with the "I" standing for "Integrated".
#
# - The most general Box-Jenkins model (ARIMA) includes difference operators, autoregressive terms, moving average terms, seasonal difference operators, seasonal autoregressive terms, and seasonal moving average terms.
#
# - The first step in developing a Box-Jenkins model is to determine if the series is stationary and if there is any significant seasonality that needs to be modeled.
#     - Stationarity can be assessed from a run sequence plot.
#     - Seasonality (or periodicity) can usually be assessed from an autocorrelation plot or spectral plot (a graphical technique for examining cyclic structure in the frequency domain)
#     - ..
#
# - [Visit](https://support.minitab.com/en-us/minitab/19/help-and-how-to/statistical-modeling/time-series/supporting-topics/time-series-models/fit-an-arima-model/). The classical approach for fitting an ARIMA model is to follow the Box-Jenkins Methodology. This is a process that uses time series analysis and diagnostics to discover good parameters for the ARIMA model.
#
# - [Winters' method:](https://support.minitab.com/en-us/minitab/19/help-and-how-to/statistical-modeling/time-series/supporting-topics/time-series-models/what-are-the-level-trend-and-seasonal-components-for-winters-method/)
#
#
# ### Seasonal Autoregressive Integrated Moving-Average with Exogenous Regressors (SARIMAX)
#
# - They are the same as the ARIMA model; specifically:
#
#         p: Trend autoregression order.
#         d: Trend difference order.
#         q: Trend moving average order.
#
# - N SARIMA, rhere are four seasonal elements that are not part of ARIMA that must be configured; they are:
#
#         P: Seasonal autoregressive order.
#         D: Seasonal difference order.
#         Q: Seasonal moving average order.
#         m: The number of time steps for a single seasonal period.
#
# - Again, SARIMA(p,d,q)(P,D,Q)m needs to be specified.
#
# - Exogenous variables are also called covariates and can be thought of as parallel input sequences that have observations at the same time steps as the original series. The primary series may be referred to as endogenous data to contrast it from the exogenous sequence(s).
#
# - The method is suitable for univariate time series with trend and/or seasonal components and exogenous variables.
#
# - http://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html
#
# - Use this for ice cream data including temperature
#
#
# ### Vector Autoregression (VAR)
#
# - The Vector Autoregression (VAR) method models the next step in each time series using an AR model. It is the generalization of AR to multiple parallel time series, e.g. multivariate time series.
#
# - The notation for the model involves specifying the order for the AR(p) model as parameters to a VAR function, e.g. VAR(p).
#
# - The method is suitable for multivariate time series without trend and seasonal components.
#
# ### Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX)
#
# - The Vector Autoregression Moving-Average with Exogenous Regressors (VARMAX) is an extension of the VARMA model that also includes the modeling of exogenous variables. It is a multivariate version of the ARMAX method.
#
# - The method is suitable for multivariate time series without trend and seasonal components with exogenous variables.
#
#
# ## More Concepts
#
# - **Endogenous** and **Exogenous**:
#
#     - Endogenous: Input variables that are influenced by other variables in the system and on which the output variable depends.
#     - Exogenous: Input variables that are not influenced by other variables in the system and on which the output variable depends.
#     - Typically, a time series forecasting problem has endogenous variables (e.g. the output is a function of some number of prior time steps) and may or may not have exogenous variables. Often, exogenous variables are ignored given the strong focus on the time series. Explicitly thinking about both variable types may help to identify easily overlooked exogenous data or even engineered features that may improve the model.
#
# - One-Step: Forecast the next time step. Multi-Step: Forecast more than one future time steps.
#
# - Static. A forecast model is fit once and used to make predictions. Dynamic. A forecast model is fit on newly available data prior to each prediction.
#
# - Univariate: One variable measured over time. Multivariate: Multiple variables measured over time.

# %% [markdown]
# # 3. Building Model <div id='BM'/>
#
# - Whatever method is used for **model identification**, model diagnostics should be performed on the selected model. [Visit](https://www.itl.nist.gov/div898/handbook/pmc/section6/pmc624.htm)
#
# - Model Identification: Use plots and summary statistics to identify trends, seasonality, and autoregression elements to get an idea of the amount of differencing and the size of the lag that will be required.
#
# - Model Checking: Use plots and statistical tests of the residual errors to determine the amount and type of temporal structure not captured by the model.
#
#
# ## Statistical Tests and Metrics
#
# - Normally, it is a good idea to investigate various data preparation techniques to rescale the data and to make it stationary. How to check whether stationary or not? Split this problem into some pieces, check one conditon at a time.
#
# - The **Augmented Dickey-Fuller test** is a type of statistical test called a unit root test.The intuition behind a unit root test is that it determines how strongly a time series is defined by a trend. Null Hypothesis (H0): If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure. p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary. Run this test on residuals again to see if trend is explained.
#
# - The **Box-Ljung test**, whether or not the residuals are random. If p-value<alpha, not evidence on random errors.
#
# - You may do a log transform of dataset to make the distribution of values more linear and better meet the expectations of a trend statistical test.
#
# - Discuss: 'I performed the Dickey–Fuller test and get 1 as p-value. Then I performed Box_Cox transform which allowed to decrease p-value to 0.96. Then I performed seasonal differentiation and p-value decreased to 0.0000. After this, I build LSTM neural network and train it. Now I want to rescale back. How?' Remember all operations need to be reversed, including the seasonal adjustment, for forcasting.
#
# - The accuracy measures are based on one-period-ahead residuals. At each point in time, the model is used to predict the Y value for the next period in time. The difference between the predicted values (fits) and the actual Y are the one-period-ahead residuals. To compare the fits of different time series models, use MAPE, MAD, MSD (lower, better).
#
# - Compare the measures of accuracy (MAPE, MAD, and MSD). Choose the model with the smallest accuracy measures.
#
# - The mean absolute percent error (MAPE) expresses accuracy as a percentage of the error. Because the MAPE is a percentage, it can be easier to understand than the other accuracy measure statistics. For example, if the MAPE is 5, on average, the forecast is off by 5%. Use to compare the fits of different time series models. Smaller values indicate a better fit. If a single model does not have the lowest values for all 3 accuracy measures, MAPE is usually the preferred measurement.
#
# - The mean absolute deviation (MAD) expresses accuracy in the same units as the data, which helps conceptualize the amount of error. Outliers have less of an effect on MAD than on MSD.
#
# - The mean square deviation (MSD) measures the accuracy of the fitted time series values. Outliers have a greater effect on MSD than on MAD.
#
# - **Detrended values** are the data with the trend component removed. The detrend values are either the differences between the observed values and the trend values (additive model) or the ratio between the observed values and the trend values (multiplicative model).
#
# - [Example with explained concepts:](https://support.minitab.com/en-us/minitab/19/help-and-how-to/statistical-modeling/time-series/how-to/decomposition/interpret-the-results/all-statistics-and-graphs/)
#
#
# ## Practical Guide in Preprocessing and Building a TS Model <div id='PG'/>
#
# - Data Preprocessing:
#     - Time series data often requires cleaning, scaling, and even transformation.
#     - Some data preparation schemes to consider include:
#
#         Differencing to remove a trend.
#         Seasonal differencing to remove seasonality.
#         Standardize to center.
#         Normalize to rescale.
#         Power Transform to make normal.
#
#     - Do transformations if applicable:
#         1. power transform
#         2. difference
#         3. standardize
#         4. normalize
#
#     - Do: Box-Cox transformation, deseasonalization and detrending
#     - Sometimes FastFourier Transformations gives a good result
#
# - Discover and remove effects.
#
# - If your data do not have a trend and do not have a seasonal component, use Moving Average or Single Exponential Smoothing.
# - If your data have a trend but do not have a seasonal component, use Trend Analysis or Double Exponential Smoothing.
# - Your data should have at least 4 or 5 full seasonal cycles. If you do not have enough full cycles, you many not have enough data to calculate reasonable estimates of the seasonal indices.
#
#
#
# ## Develop a Grid Search Framework
#
# - For the implementation of SARIMA provided by the statsmodels library, this model has hyperparameters that control the nature of the model performed for the series, trend and seasonality, specifically:
#     - order: A tuple p, d, and q parameters for the modeling of the trend.
#     - sesonal_order: A tuple of P, D, Q, and m parameters for the modeling the seasonality
#     - trend: A parameter for controlling a model of the deterministic trend as one of ‘n’,’c’,’t’,’ct’ for no trend, constant, linear, and constant with linear trend, respectively.
#
# - If you know enough about your problem to specify one or more of these parameters, then you should specify them. If not, you can try grid searching these parameters.
#
# - [Visit](https://machinelearningmastery.com/how-to-grid-search-sarima-model-hyperparameters-for-time-series-forecasting-in-python/)
#
#
# ## Issues in Modeling
#
# - Outliers. Perhaps there are corrupt or extreme outlier values that need to be identified and handled.
# - Missing. Perhaps there are gaps or missing data that need to be interpolated or imputed.
# - Complex irregular temporal structures.
# - Heavy noise.
# - Complex interrelationships between multiple variates.

# %% [markdown]
# # 4. Data Example: Transactions in an Ice Cream Store
#
# - Data set name: Time_Series_Data_YB1.csv
# - Description: One year transaction data from June 1 2019 to June 24 2020 for an icecream store.
# - Variables in Ice_Data:
#     Payment Date (07-Jul-2019 09:12 PM EDT), Tender (Debit, Cash, Visa), Amount (in dollar)
# - The goals:
#     1. Forecasting the total sales of a store each day.
#         - split the time gefore 5pm, after 5pm
#         - incorporate temperature and other useful factors to the model
#     2. Forecasting the number of costomers of a store each day
#
# - Use: AR, ARIMA, SARIMA, HWES, and SARIMAX on daily average, weekly average, (if possible: monthly average, quarterly average) with temperature, holidays, and corona time (march 18-june 16) data as X.

# %% [markdown]
# # Packs

# %%
# general
from random import random

# basics 
from numpy import log #log transformation

import pandas as pd
from pandas import datetime
from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from matplotlib import pyplot

# ts analysis from statsmodels.tsa
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.stattools import adfuller #trend test

# ts analysis from sklearn and scikit-learn
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\bilgic\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %% [markdown]
# # Import Data Sets

# %%
# Ice Cream Shop Data (transactiona): 
# https://www.w3schools.com/python/python_datetime.asp
#def parser1():
# return datetime.strptime('%d-%b-%Y',' ','%H:%M',' ','PM',' ','%Z') #'24-Jun-2020 07:36 PM EDT' in 'Payment Date' 
#ice_data_orig =read_csv("Time_Series_Data_One_Year.csv", date_parser=parser1) #original data has more variables
ice_data_orig =read_csv("Time_Series_Data_One_Year.csv", header=0, 
                        index_col=1, parse_dates=True, squeeze=True)

# ??
# extract year, month, day
# get the averaged sales by day and merge with temperature data

#ice_data =read_csv("Time_Series_Data_One_Year.csv") #original data has more variables
ice_data = ice_data_orig[['Payment Date','Amount']] #only date and sales. use 'Tender' 'Card Brand' later
print(ice_data.head(), 'Data length:', ice_data.shape)
ice_data.plot()
pyplot.show()
ice_data.hist()
pyplot.show()
ice_data.boxplot() #didn't work ['Amount']
pyplot.show()

# Monthly number of sales of Shampoo over a 3 year period (monthly)
def parser2(x):
    return datetime.strptime('190'+x, '%Y-%m')
wlink1 = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/shampoo.csv"
sha_data = read_csv(wlink1, header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser2)
#sha_data = pd.DataFrame(sha_data) #didn't work
print(sha_data.head(), 'Data length:', sha_data.shape)
sha_data.plot()
pyplot.show()
sha_data.hist()
pyplot.show()
#sha_data.values.boxplot() #didn't work
#pyplot.show()

# Intern Airline passengers
wlink2 = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
pas_data = read_csv(wlink2, header=0, index_col=0)
#sha_data = pd.DataFrame(sha_data) #didn't work
print(pas_data.head(), 'Data length:', pas_data.shape)
pas_data.plot()
pyplot.show()
pas_data.hist()
pyplot.show()
pas_data.boxplot() #didn't work
pyplot.show()

# Daily births
wlink3 = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-total-female-births.csv"
bir_data = read_csv(wlink3, header=0, index_col=0, squeeze=True)
print(bir_data.head(), 'Data length:', bir_data.shape)
bir_data.plot()
pyplot.show()
bir_data.hist()
pyplot.show()
#bir_data.boxplot() #didn't work
#pyplot.show()
# Out:
#                          Payment Date  Amount
# Tender
# Debit Card   24-Jun-2020 07:36 PM EDT   33.56
# Debit Card   24-Jun-2020 07:25 PM EDT   14.46
# Credit Card  24-Jun-2020 07:06 PM EDT   10.39
# Debit Card   24-Jun-2020 06:39 PM EDT    8.14
# Credit Card  24-Jun-2020 04:14 PM EDT   16.15 Data length: (10281, 2)
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64 Data length: (36,)
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121 Data length: (144, 1)
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: Births, dtype: int64 Data length: (365,)

# %% [markdown]
# # Ice Cream Data EDA and Preprocessing

# %%
print(ice_data.values)
print(ice_data['Payment Date'].dt.year) #??
# Out:
# [['24-Jun-2020 07:36 PM EDT' 33.56]
#  ['24-Jun-2020 07:25 PM EDT' 14.46]
#  ['24-Jun-2020 07:06 PM EDT' 10.39]
#  ...
#  ['01-Jun-2019 12:31 PM EDT' 0.01]
#  ['01-Jun-2019 12:26 PM EDT' 6.94]
#  ['01-Jun-2019 12:22 PM EDT' 7.58]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-a691d2094400> in <module>
#       1 print(ice_data.values)
# ----> 2 print(ice_data.dt.year) #??
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dt'

# %%
# Summary statistics, groupby
grouped1=ice_data_orig.groupby('Tender') #'Card Brand'
grouped2=ice_data_orig.groupby('Card Brand') #'Card Brand'
print(grouped1.describe()['Amount'].round(2))
print(grouped2.describe()['Amount'].round(2))
print(ice_data_orig['Tender'].unique()) #??
# Out:
#               count   mean   std   min   25%    50%    75%     max
# Tender
# Cash         2701.0   9.46  6.17  0.00  5.62   7.44  12.88   90.00
# Credit Card  1992.0  12.88  7.95  0.70  6.47  10.81  16.17   73.57
# Debit Card   5286.0  11.83  7.50  0.24  6.47   9.83  15.02  100.00
# Gift Cards    302.0   7.65  5.08  0.01  4.61   6.47  10.00   31.03
#              count   mean   std   min   25%    50%    75%     max
# Card Brand
# AMEX          94.0  15.14  9.46  4.07  8.38  12.94  18.04   47.17
# DISCOVER     277.0  11.78  7.89  2.11  6.47   9.83  14.60   51.39
# MAESTRO        1.0   6.47   NaN  6.47  6.47   6.47   6.47    6.47
# MC          3107.0  12.40  7.72  0.24  6.47  10.69  16.01   73.57
# VISA        3799.0  11.84  7.49  0.70  6.47  10.00  15.16  100.00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(ice_data.datetime.strftime("%d")) #??
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-2252c1d1fc7e> in <module>
# ----> 1 print(ice_data.datetime.strftime("d"))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'datetime'

# %%
# Create lagged dataset: 
# Ice Data
ice_data_values = DataFrame(ice_data.Amount)
ice_data_lagged = concat([ice_data_values.shift(4), ice_data_values.shift(3), ice_data_values.shift(2), ice_data_values.shift(1), ice_data_values], axis=1)
ice_data_lagged.columns = ['t-4','t-3','t-2','t-1', 't']
print(ice_data_lagged.tail(15))
print(ice_data.tail(15))
# Out:
#                t-4    t-3    t-2    t-1      t
# Tender
# Debit Card   22.74  14.46  17.97  10.95  27.00
# Debit Card   14.46  17.97  10.95  27.00  10.81
# Debit Card   17.97  10.95  27.00  10.81  10.86
# Cash         10.95  27.00  10.81  10.86   7.44
# Debit Card   27.00  10.81  10.86   7.44  19.94
# Debit Card   10.81  10.86   7.44  19.94  17.69
# Credit Card  10.86   7.44  19.94  17.69  17.97
# Credit Card   7.44  19.94  17.69  17.97   7.02
# Debit Card   19.94  17.69  17.97   7.02  14.74
# Debit Card   17.69  17.97   7.02  14.74  26.68
# Debit Card   17.97   7.02  14.74  26.68  11.37
# Gift Cards    7.02  14.74  26.68  11.37   0.01
# Cash         14.74  26.68  11.37   0.01   0.01
# Credit Card  26.68  11.37   0.01   0.01   6.94
# Cash         11.37   0.01   0.01   6.94   7.58
#                          Payment Date  Amount
# Tender
# Debit Card   01-Jun-2019 05:13 PM EDT   27.00
# Debit Card   01-Jun-2019 05:11 PM EDT   10.81
# Debit Card   01-Jun-2019 05:07 PM EDT   10.86
# ...

# %%
print(ice_data_lagged[['t-4','t-3','t-2','t-1', 't']])
# Out:
#                t-4    t-3    t-2    t-1      t
# Tender
# Debit Card     NaN    NaN    NaN    NaN  33.56
# Debit Card     NaN    NaN    NaN  33.56  14.46
# Credit Card    NaN    NaN  33.56  14.46  10.39
# Debit Card     NaN  33.56  14.46  10.39   8.14
# Credit Card  33.56  14.46  10.39   8.14  16.15
# ...            ...    ...    ...    ...    ...
# Debit Card   17.97   7.02  14.74  26.68  11.37
# Gift Cards    7.02  14.74  26.68  11.37   0.01
# Cash         14.74  26.68  11.37   0.01   0.01
# Credit Card  26.68  11.37   0.01   0.01   6.94
# Cash         11.37   0.01   0.01   6.94   7.58
#
# [10281 rows x 5 columns]

# %%
# correlation between two lags
ice_data_lagged.corr()
# Out:
#           t-4       t-3       t-2       t-1         t
# t-4  1.000000  0.182508  0.103536  0.098341  0.070739
# t-3  0.182508  1.000000  0.182696  0.103611  0.098404
# t-2  0.103536  0.182696  1.000000  0.182760  0.103673
# t-1  0.098341  0.103611  0.182760  1.000000  0.182784
# t    0.070739  0.098404  0.103673  0.182784  1.000000

# %%
ice_data_lagged.iloc[:100,:].plot.scatter(x='t', y='t-1', figsize=(18,8), style="*")
#ice_data_lagged[['t', 't-1']].iloc[:100,:].plot(figsize=(18,8), style="*")

# %%
# plot predictions and expected results

# split into train and test sets
X = ice_data_lagged.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
 
# persistence model
def model_persistence(x):
    return x
 
# walk-forward validation using 1 and 2 observations
predictions = list()
for x in test_X:
    yhat = model_persistence(x)
    predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print('Test MSE: %.3f' % test_score)
 
# plot predictions and expected results
pyplot.plot(train_y)
pyplot.plot([None for i in train_y] + [x for x in test_y])
pyplot.plot([None for i in train_y] + [x for x in predictions])
pyplot.show()
# Out:
# Test MSE: 99.825

# %%
# Aggregate the ice data on days, weeks, months, quarters, year with total, average, and count statistics

# %%
# Daily Temperature in Livingston county (14454) from June 1 2019 to June 24 2020

# %% [markdown]
# # Modeling Shampoo Data

# %%
# Shampoo
# Check if linear trend 
# trend test ADF: if p-value>.05, there is sign. linear trend

X = sha_data.values
result = adfuller(X) #can do partial: split and run. for trend, see high p-vlues
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 3.060142
# p-value: 1.000000
# Critical Values:
# 	1%: -3.724
# 	5%: -2.986
# 	10%: -2.633

# %%
# test_stationariy using rolling stat and DF test
# use 
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(bir_data)
#test_stationarity(ts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-1d9d5f61acde> in <module>
# ----> 1 test_stationarity(bir_data)
#       2 #test_stationarity(ts)
#
# <ipython-input-88-04dd9b4ac796> in test_stationarity(timeseries)
#       4
#       5     #Determing rolling statistics
# ----> 6     rolmean = pd.rolling_mean(timeseries, window=12)
#       7     rolstd = pd.rolling_std(timeseries, window=12)
#       8
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'rolling_mean'

# %%
# Try data set ? issues?
# create a lagged representation
values = pd.DataFrame(sha_data.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
print(dataframe.head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-175fba0c3b9e> in <module>
#       2 # create a lagged representation
#       3 values = pd.DataFrame(sha_data.values)
# ----> 4 dataframe = concat([values.shift(1), values], axis=0)
#       5 dataframe.columns = ['t-1', 't+1']
#       6 print(dataframe.head(5))
#
# NameError: name 'concat' is not defined

# %%
print(pd.DataFrame(sha_data.values))
# Out:
#         0
# 0   266.0
# 1   145.9
# 2   183.1
# 3   119.3
# 4   180.3
# 5   168.5
# 6   231.8
# 7   224.5
# 8   192.8
# 9   122.9
# 10  336.5
# 11  185.9
# 12  194.3
# 13  149.5
# 14  210.1
# 15  273.3
# 16  191.4
# 17  287.0
# 18  226.0
# 19  303.6
# 20  289.9
# 21  421.6
# 22  264.5
# 23  342.3
# 24  339.7
# 25  440.4
# 26  315.9
# 27  439.3
# 28  401.3
# 29  437.4
# 30  575.5
# 31  407.6
# 32  682.0
# 33  475.3
# 34  581.3
# 35  646.9

# %%
# autocorrelation_plot
from pandas.plotting import autocorrelation_plot

#autocorrelation_plot(ice_data)
#pyplot.show()

autocorrelation_plot(sha_data)
pyplot.show()

# %%
#fit an ARIMA model to the entire Shampoo Sales dataset and review the residual errors.
#ARIMA() and passing in the p, d, and q parameters
#ARIMA(5,1,0) model: the lag value to 5 for autoregression, uses a difference order of 1 to make the time series stationary, and uses a moving average model of 0.
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# fit model
model = ARIMA(sha_data, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())

# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                   35
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -196.170
# Method:                       css-mle   S.D. of innovations             64.241
# Date:                Thu, 25 Jun 2020   AIC                            406.340
# Time:                        18:33:04   BIC                            417.227
# Sample:                    02-01-1901   HQIC                           410.098
#                          - 12-01-1903
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            12.0649      3.652      3.304      0.001       4.908      19.222
# ar.L1.D.Sales    -1.1082      0.183     -6.063      0.000      -1.466      -0.750
# ar.L2.D.Sales    -0.6203      0.282     -2.203      0.028      -1.172      -0.068
# ...

# %%
#forecast and plot the prediction and expected value each iteration.

from sklearn.metrics import mean_squared_error

X = sha_data.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
   
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)

# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=349.117692, expected=342.300000
# predicted=306.512866, expected=339.700000
# predicted=387.376465, expected=440.400000
# predicted=348.154144, expected=315.900000
# predicted=386.308801, expected=439.300000
# predicted=356.082088, expected=401.300000
# predicted=446.379471, expected=437.400000
# predicted=394.737288, expected=575.500000
# predicted=434.915413, expected=407.600000
# predicted=507.923472, expected=682.000000
# predicted=435.482761, expected=475.300000
# predicted=652.743901, expected=581.300000
# predicted=546.343472, expected=646.900000
# Test MSE: 6958.326

# %% [markdown]
# ## 1. ARIMA

# %%
# contrived dataset
data = [x + random() for x in range(1, 100)]

# fit model 
# ARIMA example
model = ARIMA(data, order=(1, 1, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(len(data), len(data), typ='levels')
print(yhat)

# %% [markdown]
# # 2. SARIMAX

# %%
# SARIMAX example
from statsmodels.tsa.statespace.sarimax import SARIMAX
from random import random

# contrived dataset
data1 = [x + random() for x in range(1, 100)]
data2 = [x + random() for x in range(101, 200)]

# fit model SARIMAX
model = SARIMAX(data1, exog=data2, order=(1, 1, 1), seasonal_order=(0, 0, 0, 0))
model_fit = model.fit(disp=False)
# make prediction
exog2 = [200 + random()]
yhat = model_fit.predict(len(data1), len(data1), exog=[exog2])
print(yhat)
# Out:
# [100.15031385]

# %% [markdown]
# # 3. VAR

# %%
# VARMAX example
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random

# contrived dataset with dependency
data = list()
for i in range(100):
    v1 = random()
    v2 = v1 + random()
    row = [v1, v2]
    data.append(row)
data_exog = [x + random() for x in range(100)]

# fit model
model = VARMAX(data, exog=data_exog, order=(1, 1))
model_fit = model.fit(disp=False)
# make prediction
data_exog2 = [[100]]
yhat = model_fit.forecast(exog=data_exog2)
print(yhat)
# Out:
# C:\Users\bilgic\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# [[0.4925831  0.97284867]]
# C:\Users\bilgic\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\bilgic\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)

# %%
# Create lagged dataset
sha_data_values = DataFrame(sha_data.values)
sha_data_lagged = concat([sha_data_values.shift(1), sha_data_values], axis=1)
sha_data_lagged.columns = ['t-1', 't+1']
print(sha_data_lagged.head(5))
 
# split into train and test sets
X = sha_data_lagged.values
train_size = int(len(X) * 0.66)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]
 
# persistence model
def model_persistence(x):
    return x
 
# walk-forward validation
predictions = list()
for x in test_X:
    yhat = model_persistence(x)
    predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print('Test MSE: %.3f' % test_score)
 
# plot predictions and expected results
pyplot.plot(train_y)
pyplot.plot([None for i in train_y] + [x for x in test_y])
pyplot.plot([None for i in train_y] + [x for x in predictions])
pyplot.show()
# Out:
#      t-1    t+1
# 0    NaN  266.0
# 1  266.0  145.9
# 2  145.9  183.1
# 3  183.1  119.3
# 4  119.3  180.3
# Test MSE: 17730.518

# %% [markdown]
# ## Quarterly average of wholesale price over

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import statsmodels.api as sm
import matplotlib.pyplot as plt
from datetime import datetime
import requests
from io import BytesIO
# Register converters to avoid warnings
pd.plotting.register_matplotlib_converters()

# %%
# Dataset: quarterly average of wholesale price over time during 31 yrs
# the Wholesale price index (WPI)
# https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_sarimax_stata.html
wpi1 = requests.get('https://www.stata-press.com/data/r12/wpi1.dta').content
s_data = pd.read_stata(BytesIO(wpi1))
data.index = s_data.t
print(s_data.head(), 'Data length:', s_data.shape)
print(s_data.tail(), 'Data length:', s_data.shape)

s_data.wpi.plot()
pyplot.show()

s_data.wpi.hist()
pyplot.show()

s_data.ln_wpi.plot()
pyplot.show()

s_data.ln_wpi.hist()
pyplot.show()

s_data.boxplot() #didn't work ['Amount']
pyplot.show()
# Out:
#          wpi          t    ln_wpi
# 0  30.700001 1960-01-01  3.424263
# 1  30.799999 1960-04-01  3.427515
# 2  30.700001 1960-07-01  3.424263
# 3  30.700001 1960-10-01  3.424263
# 4  30.799999 1961-01-01  3.427515 Data length: (124, 3)
#             wpi          t    ln_wpi
# 119  109.400002 1989-10-01  4.695011
# 120  111.000000 1990-01-01  4.709530
# 121  110.800003 1990-04-01  4.707727
# 122  112.800003 1990-07-01  4.725616
# 123  116.199997 1990-10-01  4.755313 Data length: (124, 3)

# %%
# Set the frequency
s_data.index.freq="QS-OCT"

# the Wholesale price index (WPI) is growing over time (i.e. is not stationary)
# so integrated of order 1, so that the difference is assumed to be stationary, and fit a model with one autoregressive lag and one moving average lag, as well as an intercept term.

# Fit the model ARIMA(1,1,1)
mod = sm.tsa.statespace.SARIMAX(s_data['wpi'], trend='c', order=(1,1,1))
res = mod.fit(disp=False)
print(res.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                    wpi   No. Observations:                  124
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -135.351
# Date:                Sat, 27 Jun 2020   AIC                            278.703
# Time:                        16:25:21   BIC                            289.951
# Sample:                    01-01-1960   HQIC                           283.272
#                          - 10-01-1990
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0943      0.068      1.389      0.165      -0.039       0.227
# ar.L1          0.8742      0.055     16.028      0.000       0.767       0.981
# ma.L1         -0.4120      0.100     -4.119      0.000      -0.608      -0.216
# ...

# %%
# New Dataset
friedman2 = requests.get('https://www.stata-press.com/data/r12/friedman2.dta').content
raw = pd.read_stata(BytesIO(friedman2))
raw.index = raw.time
raw.index.freq = "QS-OCT"
data = raw.loc[:'1981']

# Variables
endog = data.loc['1959':, 'consump']
exog = sm.add_constant(data.loc['1959':, 'm2'])
nobs = endog.shape[0]

# Fit the model
mod = sm.tsa.statespace.SARIMAX(endog.loc[:'1978-01-01'], exog=exog.loc[:'1978-01-01'], order=(1,0,1))
fit_res = mod.fit(disp=False)
print(fit_res.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                consump   No. Observations:                   77
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                -243.316
# Date:                Sat, 27 Jun 2020   AIC                            496.633
# Time:                        16:43:48   BIC                            508.352
# Sample:                    01-01-1959   HQIC                           501.320
#                          - 01-01-1978
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6740     18.487      0.036      0.971     -35.559      36.907
# m2             1.0379      0.021     50.339      0.000       0.997       1.078
# ar.L1          0.8775      0.059     14.858      0.000       0.762       0.993
# ...

# %%
# In-sample one-step-ahead predictions
predict = res.get_prediction()
predict_ci = predict.conf_int()

# Dynamic predictions
predict_dy = res.get_prediction(dynamic='1978-01-01')
predict_dy_ci = predict_dy.conf_int()

# %%
# Graph
fig, ax = plt.subplots(figsize=(9,4))
npre = 4
ax.set(title='Personal consumption', xlabel='Date', ylabel='Billions of dollars')

# Plot data points
data.loc['1977-07-01':, 'consump'].plot(ax=ax, style='o', label='Observed')

# Plot predictions
predict.predicted_mean.loc['1977-07-01':].plot(ax=ax, style='r--', label='One-step-ahead forecast')
ci = predict_ci.loc['1977-07-01':]
ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)
predict_dy.predicted_mean.loc['1977-07-01':].plot(ax=ax, style='g', label='Dynamic forecast (1978)')
ci = predict_dy_ci.loc['1977-07-01':]
ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='g', alpha=0.1)

legend = ax.legend(loc='lower right')

# %%
# Prediction error

# Graph
fig, ax = plt.subplots(figsize=(9,4))
npre = 4
ax.set(title='Forecast error', xlabel='Date', ylabel='Forecast - Actual')

# In-sample one-step-ahead predictions and 95% confidence intervals
predict_error = predict.predicted_mean - endog
predict_error.loc['1977-10-01':].plot(ax=ax, label='One-step-ahead forecast')
ci = predict_ci.loc['1977-10-01':].copy()
ci.iloc[:,0] -= endog.loc['1977-10-01':]
ci.iloc[:,1] -= endog.loc['1977-10-01':]
ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], alpha=0.1)

# Dynamic predictions and 95% confidence intervals
predict_dy_error = predict_dy.predicted_mean - endog
predict_dy_error.loc['1977-10-01':].plot(ax=ax, style='r', label='Dynamic forecast (1978)')
ci = predict_dy_ci.loc['1977-10-01':].copy()
ci.iloc[:,0] -= endog.loc['1977-10-01':]
ci.iloc[:,1] -= endog.loc['1977-10-01':]
ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)

legend = ax.legend(loc='lower left');
legend.get_frame().set_facecolor('w')

# %% [markdown]
# # How to Grid Search
#
# https://machinelearningmastery.com/how-to-grid-search-sarima-model-hyperparameters-for-time-series-forecasting-in-python/

# %% [markdown]
# # Useful Code

# %%
# Demo on season
import statsmodels.api as sm

dta = sm.datasets.co2.load_pandas().data
# deal with missing values. see issue
dta.co2.interpolate(inplace=True)

res = sm.tsa.seasonal_decompose(dta.co2)
resplot = res.plot()

# %%
# create date time features of a dataset
from pandas import read_csv
from pandas import DataFrame
series = read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame()
dataframe['month'] = [series.index[i].month for i in range(len(series))]
dataframe['day'] = [series.index[i].day for i in range(len(series))]
dataframe['temperature'] = [series[i] for i in range(len(series))]
print(dataframe.head(5))
# Out:
#    month  day  temperature
# 0      1    1         20.7
# 1      1    2         17.9
# 2      1    3         18.8
# 3      1    4         14.6
# 4      1    5         15.8

# %%
print(series.head())
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# Name: Temp, dtype: float64

# %% [markdown]
# # Again, Ice Cream Data and Daily Temperature

# %%
# Import ice cream data with various date define
#def parser1():
#    return datetime.strptime('%d-%b-%Y',' ','%H:%M',' ','PM',' ','%Z') #'24-Jun-2020 07:36 PM EDT' in 'Payment Date' 
#ice_data =read_csv("Time_Series_Data_One_Year.csv", date_parser=parser1) #original data has more variables
ice_data_orig =read_csv("Time_Series_Data_One_Year.csv", header=0, index_col=0, parse_dates=True, squeeze=True)
print(ice_data)

ice_data = ice_data_orig[['Amount']] 
#ice_data = ice_data[['Payment Date','Amount']] 
print(ice_data.head(), 'Data length:', ice_data.shape)
ice_data.plot()
pyplot.show()
ice_data.hist()
pyplot.show()
ice_data.boxplot()
pyplot.show()
# Out:
# C:\Users\bilgic\AppData\Local\Continuum\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\bilgic\AppData\Local\Continuum\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
#                          Payment Date  Amount
# Tender
# Debit Card   24-Jun-2020 07:36 PM EDT   33.56
# Debit Card   24-Jun-2020 07:25 PM EDT   14.46
# Credit Card  24-Jun-2020 07:06 PM EDT   10.39
# Debit Card   24-Jun-2020 06:39 PM EDT    8.14
# Credit Card  24-Jun-2020 04:14 PM EDT   16.15
# ...

# %%
# Import temperature data
temp_data =read_csv("Time_Series_Data_One_Year_Temperature.csv", header=0, index_col=1, parse_dates=True, squeeze=True)
print(temp_data)

temp_data = temp_data[['TAVG']] 
#ice_data = ice_data[['Payment Date','Amount']] 
print(temp_data.head(), 'Data length:', temp_data.shape)
temp_data.plot(figsize=(18, 6))
pyplot.show()
temp_data.hist()
pyplot.show()
temp_data.boxplot()
pyplot.show()
# Out:
#                 STATION   AWND  TAVG  TMAX  TMIN  Temp_Diff
# DATE
# 2019-06-01  USW00014768   8.05  66.0    79    57         22
# 2019-06-02  USW00014768   9.62  62.0    68    52         16
# 2019-06-03  USW00014768  13.87  54.0    63    43         20
# 2019-06-04  USW00014768   6.71  55.0    66    43         23
# 2019-06-05  USW00014768   5.59  66.0    79    58         21
# ...                 ...    ...   ...   ...   ...        ...
# 2020-06-20  USW00014768   5.37  75.0    86    63         23
# 2020-06-21  USW00014768   4.47  76.0    88    64         24
# 2020-06-22  USW00014768   6.49  77.0    89    69         20
# 2020-06-23  USW00014768   9.84  74.0    85    65         20
# 2020-06-24  USW00014768  16.78  68.0    75    58         17
#
# [390 rows x 6 columns]
#             TAVG
# DATE
# 2019-06-01  66.0
# 2019-06-02  62.0
# 2019-06-03  54.0
# 2019-06-04  55.0
# 2019-06-05  66.0 Data length: (390, 1)

# %%
#extract year, month, day, hour
ice_dataframe = DataFrame()
ice_dataframe['year'] = [ice_data.index[i].year for i in range(len(ice_data))]
ice_dataframe['month'] = [ice_data.index[i].month for i in range(len(ice_data))]
ice_dataframe['day'] = [ice_data.index[i].day for i in range(len(ice_data))]
#ice_dataframe['hour'] = [ice_data.index[i].hour for i in range(len(ice_data))]
ice_dataframe['Transactions'] = [ice_data['Amount'][i] for i in range(len(ice_data))] #didn't work. then worked print(ice_data['Amount'][0])
print(ice_dataframe.head(5))
print(ice_dataframe.tail(5))
# Out:
#    year  month  day  Transactions
# 0  2020      6   24         33.56
# 1  2020      6   24         14.46
# 2  2020      6   24         10.39
# 3  2020      6   24          8.14
# 4  2020      6   24         16.15
#        year  month  day  Transactions
# 10276  2019      6    1         11.37
# 10277  2019      6    1          0.01
# 10278  2019      6    1          0.01
# 10279  2019      6    1          6.94
# 10280  2019      6    1          7.58

# %%
# create aggregated data set on count, daily
ice_dataframe.groupby('month').mean() #https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.groupby.GroupBy.mean.html
ice_dataframe_ct = ice_dataframe.groupby(['year', 'month', 'day']).count()
print(ice_dataframe_ct)
print(ice_dataframe_ct.shape)

ice_dataframe_ct.plot(figsize=(18, 6))
pyplot.show()
# Out:
#                 Transactions
# year month day
# 2019 6     1              24
#            2              31
#            3              70
#            4              23
#            5              22
# ...                      ...
# 2020 6     20             16
#            21             28
#            22             50
#            23             24
#            24             19
#
# [387 rows x 1 columns]
# (387, 1)

# %%
# ?? create aggregated data set on count, weekly

# %%
print(ice_dataframe.describe())
print(ice_dataframe_ct.describe())
print(temp_data.describe())
# Out:
#                year         month           day  Transactions
# count  10281.000000  10281.000000  10281.000000  10281.000000
# mean    2019.334403      6.870927     15.719774     11.286906
# std        0.471804      3.145556      8.785709      7.338972
# min     2019.000000      1.000000      1.000000      0.000000
# 25%     2019.000000      5.000000      8.000000      6.470000
# 50%     2019.000000      7.000000     16.000000      9.410000
# 75%     2020.000000      9.000000     23.000000     14.040000
# max     2020.000000     12.000000     31.000000    100.000000
#        Transactions
# count    387.000000
# mean      26.565891
# std       22.392580
# min        1.000000
# 25%       13.000000
# 50%       22.000000
# 75%       32.000000
# max      149.000000
#              TAVG
# count  389.000000
# mean    50.838046
# std     17.588128
# min     12.000000
# 25%     36.000000
# 50%     50.000000
# 75%     67.000000
# max     82.000000

# %%
# plots
print(ice_dataframe)
ice_dataframe.groupby(['day','month'])['Amount'].count().unstack().plot(figsize=(18,8))
ice_dataframe.groupby(['day','year'])['Amount'].count().unstack().plot(figsize=(18,8))
# Out:
#        year  month  day  Transactions
# 0      2020      6   24         33.56
# 1      2020      6   24         14.46
# 2      2020      6   24         10.39
# 3      2020      6   24          8.14
# 4      2020      6   24         16.15
# ...     ...    ...  ...           ...
# 10276  2019      6    1         11.37
# 10277  2019      6    1          0.01
# 10278  2019      6    1          0.01
# 10279  2019      6    1          6.94
# 10280  2019      6    1          7.58
#
# [10281 rows x 4 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-adc8992d68d6> in <module>
#       1 # plots
#       2 print(ice_dataframe)
# ----> 3 ice_dataframe.groupby(['day','month'])['Amount'].count().unstack().plot(figsize=(18,8))
#       4 ice_dataframe.groupby(['day','year'])['Amount'].count().unstack().plot(figsize=(18,8))
#
# ...

# %%
# boxplots: daily, monthly
import seaborn as sns # visualization
import matplotlib.pyplot as plt

#data = pd.DataFrame(ice_dataframe['year', 'month', 'day', 'Amount']) #ice_dataframe['year', 'month', 'Amount']
#data = pd.concat([ice_dataframe['month'], ice_dataframe['Amount']], axis=1)
f, ax = plt.subplots(figsize=(18, 8))
#fig = sns.boxplot(x='month', y='Amount', data=data, showfliers=False, hue="Type")
fig = sns.boxplot(x='year', y='Transactions', data=ice_dataframe, showfliers=False, hue="month", orient="v")
#fig = sns.boxplot(x='day', y='Amount', data=ice_dataframe, showfliers=False)
#fig = sns.boxplot(x='month', y='Amount', data=ice_dataframe, showfliers=False)

# %%
# ?? working
# concatenate: temp_data, ice_dataframe_ct
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/

pd.concat([temp_data, ice_dataframe_ct], axis=0, sort=True)
# Out:
#                      TAVG  Transactions
# 2019-06-01 00:00:00  66.0           NaN
# 2019-06-02 00:00:00  62.0           NaN
# 2019-06-03 00:00:00  54.0           NaN
# 2019-06-04 00:00:00  55.0           NaN
# 2019-06-05 00:00:00  66.0           NaN
# ...                   ...           ...
# (2020, 6, 20)         NaN          16.0
# (2020, 6, 21)         NaN          28.0
# (2020, 6, 22)         NaN          50.0
# (2020, 6, 23)         NaN          24.0
# (2020, 6, 24)         NaN          19.0
#
# [777 rows x 2 columns]

# %%
# Run plot, AutoCorrelation and Partial Autocorrelation Plots on Daily and Weekly sales
# import the plotting functions for act and pacf  
# read https://www.itl.nist.gov/div898/handbook/pmc/section6/pmc622.htm
# Run plot, AutoCorrelation and Partial Autocorrelation Plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(18,8)) #when .subplots, it plots on the same graph if ax=ax for both
#plt.figure( figsize=(18,8) )
plot_acf(ice_dataframe_ct['Transactions'], lags=30, ax=ax); #figsize=(18,8)
#plot_pacf(ice_dataframe_ct['Amount'], lags=100, ax=ax);
plot_pacf(ice_dataframe_ct['Transactions'], lags=30, ax=ax);

# %%
plot_pacf(ice_dataframe_ct['Transactions'], lags=60);

# %%
# simple fig size
pyplot.figure(figsize=(18,8))
pyplot.subplot(211)
plot_acf(ice_dataframe_ct['Transactions'], lags=100, ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(ice_dataframe_ct['Transactions'], lags=100, ax=pyplot.gca())
pyplot.show()

# %%
# lagged data on daily counts

# Create lagged dataset: 
# Ice Data
ice_dataframe_values = DataFrame(ice_dataframe_ct.Transactions)
ice_dataframe_lagged = concat([ice_dataframe_values.shift(1), ice_dataframe_values], axis=1)
ice_dataframe_lagged.columns = ['t-1', 't']
print(ice_dataframe_lagged.tail(15))
print(ice_dataframe_ct.tail(15))
# Out:
#                  t-1   t
# year month day
# 2020 6     10   30.0  23
#            11   23.0  14
#            12   14.0  24
#            13   24.0  27
#            14   27.0  28
#            15   28.0  71
#            16   71.0  25
#            17   25.0  26
#            18   26.0  24
#            19   24.0  20
#            20   20.0  16
#            21   16.0  28
#            22   28.0  50
#            23   50.0  24
#            24   24.0  19
#                 Transactions
# year month day
# 2020 6     10             23
#            11             14
#            12             24
#            13             27
#            14             28
#            15             71
#            16             25
#            17             26
#            18             24
#            19             20
#            20             16
#            21             28
#            22             50
#            23             24
#            24             19

# %%
# plot ts of differenced data on counts
# then obtain autocorr
ice_dataframe_lagged['diff1'] = ice_dataframe_lagged['t'] - ice_dataframe_lagged['t-1']
print(ice_dataframe_lagged['diff1'])

#TS plot of differenced counts
ice_dataframe_lagged['diff1'].plot(figsize=(18, 6))
pyplot.show()

#ACF ??
plot_acf(ice_dataframe_lagged['diff1'], lags=7);
# Out:
# year  month  day
# 2019  6      1       NaN
#              2       7.0
#              3      39.0
#              4     -47.0
#              5      -1.0
#                     ...
# 2020  6      20     -4.0
#              21     12.0
#              22     22.0
#              23    -26.0
#              24     -5.0
# Name: diff1, Length: 387, dtype: float64

# %%
#TS plot of temperature
temp_data['TAVG'].plot(figsize=(18, 6))
pyplot.show()

#??
plot_pacf(temp_data['TAVG'], lags=10);
