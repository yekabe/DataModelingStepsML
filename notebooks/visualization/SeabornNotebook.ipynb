# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#a = pd.read_csv("~/Documents/workspace/seaborn-data/flights.csv")

# %%
flight_data = sns.load_dataset("flights")

# %%
flight_data.shape 
flight_data.tail(10)
# Out:
#      year      month  passengers
# 134  1960      March         419
# 135  1960      April         461
# 136  1960        May         472
# 137  1960       June         535
# 138  1960       July         622
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432

# %%
sns.relplot(x="passengers", y="month", data=flight_data)

# %%
sns.relplot(x="passengers", y="month", hue="year", data=flight_data) # adds dimension

# %%
flight_data.year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960])

# %%
tips_data = sns.load_dataset("tips")

# %%
tips_data.shape, tips_data.head()
# Out:
# ((244, 7),
#     total_bill   tip     sex smoker  day    time  size
#  0       16.99  1.01  Female     No  Sun  Dinner     2
#  1       10.34  1.66    Male     No  Sun  Dinner     3
#  2       21.01  3.50    Male     No  Sun  Dinner     3
#  3       23.68  3.31    Male     No  Sun  Dinner     2
#  4       24.59  3.61  Female     No  Sun  Dinner     4)

# %%
#x = pd.DataFrame({"Day":[1,2,3,4,5,6,7], "Grocery":[30,80,50,30, 79, 39, 33], "Clothes":[13,40,34,23,54,67,98]})
#y = pd.DataFrame({"Day":[8,9,10,11,12,13,14], "Grocery":[30,80,55,30, 71, 39, 30], "Clothes":[10,90,34,20,54,67,98]})
with sns.axes_style("white"):
    sns.jointplot(x="total_bill", y="tip",data=tips_data, kind="kde")

# %%
#tips_data.groupby("time").mean()
tips_data.groupby("time").std()
# Out:
#         total_bill       tip      size
# time
# Lunch     7.713882  1.205345  1.040024
# Dinner    9.142029  1.436243  0.910241

# %%
tips_data.groupby("time").mean()
# Out:
#         total_bill       tip      size
# time
# Lunch    17.168676  2.728088  2.411765
# Dinner   20.797159  3.102670  2.630682

# %%
sns.relplot(x="day", y="tip", data=tips_data, kind= "line" )

# %%
sns.catplot(x="day", y="total_bill", data=tips_data)

# %%
sns.catplot(x="day", y="tip", data=tips_data, kind="violin")

# %%
sns.catplot(x="day", y="tip", data=tips_data, kind="boxen")

# %%
# #univariate or univariate

# %%
from scipy import stats

# %%
#univariate dist 
c = np.random.normal(loc=5, size= 100, scale=2)
c
# Out:
# array([5.03951767, 4.30379948, 4.88487545, 6.87402496, 3.32249508,
#        3.88721736, 3.83675944, 5.14143882, 5.50299605, 5.81987644,
#        4.11996201, 5.97596161, 3.86177828, 3.87045829, 3.8306773 ,
#        3.45432041, 2.63415233, 6.35968285, 9.89030384, 4.60050119,
#        5.55592265, 5.39157783, 9.43014799, 6.03027452, 3.81301343,
#        3.4216717 , 5.35848039, 7.16762589, 9.4618701 , 3.12677091,
#        6.84136543, 2.31451566, 1.85001522, 5.4435402 , 4.07457185,
#        3.62670618, 5.50871887, 0.0803996 , 4.24915627, 2.24820149,
#        6.43202259, 5.96734653, 3.67529838, 8.36409281, 7.46814244,
#        3.67160732, 6.39220796, 3.06356658, 7.61806038, 5.39404426,
#        5.63725599, 5.72816907, 1.82614776, 6.83054604, 6.21776653,
#        8.07677484, 5.13654627, 2.011493  , 4.53683949, 7.90642487,
#        6.79318588, 5.55625353, 3.85160199, 3.50049168, 2.87067219,
#        8.43898952, 4.92854389, 6.95026212, 5.24498543, 4.56457869,
# ...

# %%
sns.distplot(c)

# %%
x = pd.DataFrame({"Day":[1,2,3,4,5,6,7], "Grocery":[30,80,50,30, 79, 39, 33], "Clothes":[13,40,34,23,54,67,98]})
y = pd.DataFrame({"Day":[8,9,10,11,12,13,14], "Grocery":[30,80,55,30, 71, 39, 30], "Clothes":[10,90,34,20,54,67,98]})
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="kde")

# %%
#x = pd.DataFrame({"Day":[1,2,3,4,5,6,7], "Grocery":[30,80,50,30, 79, 39, 33], "Clothes":[13,40,34,23,54,67,98]})
#y = pd.DataFrame({"Day":[8,9,10,11,12,13,14], "Grocery":[30,80,55,30, 71, 39, 30], "Clothes":[10,90,34,20,54,67,98]})
with sns.axes_style("white"):
    sns.jointplot(x="total_bill", y="tip",data=tips_data, kind="reg"),sns.jointplot(x="total_bill", y="tip",data=tips_data, kind="kde")

# %%
sns.boxplot(x="tip", y="day", data=tips_data, orient="h")

# %%
sns.boxplot(x="day", y="tip", data=tips_data, orient="v")

# %%
sns.boxplot(x="day", y="total_bill", data=tips_data)

# %%
sns.boxplot(x="day", y="total_bill", data=tips_data)
sns.despine(offset={"x":10, "y":10},trim= True)

# %%
c = sns.color_palette()
sns.palplot(c)

# %%
sns.boxplot(x="day", y="total_bill", data=tips_data,whis=.8) # quartile change with whis
# 1st vs 3rd quartile  = interquartile
# .8 interquartile range above 3rd quartile (extreme outlier 3 dur )(1.5 quartile is standard )
sns.despine(offset={"x":10, "y":10},trim= True)
